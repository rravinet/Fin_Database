# %%
import sqlalchemy
import pandas as pd
import numpy as np
from polygon import RESTClient
import datetime as dt
import os
from dotenv import load_dotenv
from connect import engine, Base, Company_Financials
from sqlalchemy import select, inspect
from sqlalchemy.orm import sessionmaker
from sqlalchemy.sql import func
import logging
from sqlalchemy.dialects.postgresql import JSONB
# from log_config import setup_logging
import pytz
import json

# %%
setup_logging()

# %%
load_dotenv()
key = os.getenv("API_KEY")

# %%
client = RESTClient(api_key=key)

# %%
events = client.get_ticker_events("META")
print(events)
# Out:
# TickerChangeResults(name='Meta Platforms, Inc. Class A Common Stock', composite_figi='BBG000MM2P62', cik='0001326801', events=[{'ticker_change': {'ticker': 'META'}, 'type': 'ticker_change', 'date': '2022-06-09'}, {'ticker_change': {'ticker': 'FB'}, 'type': 'ticker_change', 'date': '2012-05-18'}])

# %%
events
# Out:
# TickerChangeResults(name='Meta Platforms, Inc. Class A Common Stock', composite_figi='BBG000MM2P62', cik='0001326801', events=[{'ticker_change': {'ticker': 'META'}, 'type': 'ticker_change', 'date': '2022-06-09'}, {'ticker_change': {'ticker': 'FB'}, 'type': 'ticker_change', 'date': '2012-05-18'}])

# %%
wiki = 'http://en.wikipedia.org/wiki'
djia_ticker_list = wiki + '/Dow_Jones_Industrial_Average'
sp500_tickers_list = wiki + '/List_of_S%26P_500_companies'
tickersSP500 = pd.read_html(sp500_tickers_list)[0].Symbol.to_list()
djia_tickers = pd.read_html(djia_ticker_list)[1].Symbol.to_list()

# %%
class Company_Financials_updater:
    def __init__(self, tickers, engine):
        self.tickers = tickers if isinstance(tickers, list) else [tickers]
        self.engine = engine
        
    def transform_data(self, df):
        df['start_date'] = pd.to_datetime(df['start_date'],errors='coerce')
        df['end_date'] = pd.to_datetime(df['end_date'],errors='coerce')
        df['filing_date'] = pd.to_datetime(df['filing_date'],errors='coerce')
        df['filing_date'] = df['filing_date'].dt.strftime('%Y-%m-%d %H:%M:%S') if df['filing_date'] is not pd.NaT else None
        df.drop(columns=['cik', 'source_filing_file_url', 'source_filing_url'], inplace=True)
        df['financials'] = df['financials'].apply(json.dumps)
        transformed = df.to_dict(orient='records')
        return transformed
    
    def need_for_update(self):
        pass
        
    def update_data(self,client):
        with self.engine.connect() as conn:
            all_data = []
            logging.info(f"Updating company financials for {self.tickers}")
            for ticker in self.tickers:
                resp = client.vx.list_stock_financials(ticker)
                ticker_df = pd.DataFrame(resp)
                
                if not ticker_df.empty:
                    transformed_data = self.transform_data(ticker_df)
                    all_data.extend(transformed_data)
                else:
                    print(f"No data for {ticker}")
        return all_data        
                    
            # if all_data:
            #     try:
            #         conn.execute(Company_Financials.__table__.insert(), all_data)
            #         logging.info("Data insert completed successfully.")

            #     except Exception as e:
            #             logging.error(f"Error updating company data for {ticker}: {e}")

# %%
updater =  Company_Financials_updater(tickers = 'AAPL', engine = engine)

# %%
t = updater.update_data(client)

# %%
t
# Out:
# [{'company_name': 'APPLE INC',
#   'end_date': Timestamp('2023-12-30 00:00:00'),
#   'filing_date': nan,
#   'financials': '{"balance_sheet": {"inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 6511000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43666000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 143692000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 39441000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 279414000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 166156000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 106000000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 74100000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 137181000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 75827000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 74100000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 353514000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 209822000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 133973000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 353514000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 145441000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 58146000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 20000000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -103510000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 104447000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 104447000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 104447000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 6.46, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 212035000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 173671000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Op ...
#   'fiscal_period': 'TTM',
#   'fiscal_year': '',
#   'start_date': Timestamp('2022-12-31 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2023-12-30 00:00:00'),
#   'filing_date': '2024-02-02 00:00:00',
#   'financials': '{"balance_sheet": {"other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 166156000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 74100000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 133973000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 353514000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 74100000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 353514000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 209822000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 145441000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 6511000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 58146000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 106000000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 137181000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43666000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 143692000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 39441000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 75827000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 279414000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 11237000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -30585000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 35990000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 35990000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 35990000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 2.19, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 64720000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 54855000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operatin ...
#   'fiscal_period': 'Q1',
#   'fiscal_year': '2024',
#   'start_date': Timestamp('2023-10-01 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2023-09-30 00:00:00'),
#   'filing_date': nan,
#   'financials': '{"balance_sheet": {"liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 352583000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 143566000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 62146000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 82697000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 62611000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 290437000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 352583000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 6331000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 145308000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 40026000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 137235000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 62146000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43715000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 105103000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 145129000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 209017000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 165302000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 839000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -23153000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 23305000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 23305000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 23305000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.4699999999999998, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 49071000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 40427000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label ...
#   'fiscal_period': 'Q4',
#   'fiscal_year': '2023',
#   'start_date': Timestamp('2023-07-02 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2023-09-30 00:00:00'),
#   'filing_date': '2023-11-03 00:00:00',
#   'financials': '{"balance_sheet": {"liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 352583000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 143566000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 62146000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 62146000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 40026000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 82697000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 145129000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 105103000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 145308000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43715000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 62611000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 290437000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 165302000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 137235000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 209017000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 6331000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 352583000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 5760000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -108488000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 96652000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 96652000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 96652000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 6.16, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 214137000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 169148000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operat ...
#   'fiscal_period': 'FY',
#   'fiscal_year': '2023',
#   'start_date': Timestamp('2022-09-25 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2023-07-01 00:00:00'),
#   'filing_date': '2023-08-04 00:00:00',
#   'financials': '{"balance_sheet": {"inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 7351000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 122659000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 46699000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 335038000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 168829000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 212379000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 44501000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 149801000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 124963000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 60274000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 78264000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 274764000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 335038000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 105300000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 60274000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 115308000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43550000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 2769000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -24048000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 19826000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 19826000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 19826000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.27, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 45384000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 36413000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating ...
#   'fiscal_period': 'Q3',
#   'fiscal_year': '2023',
#   'start_date': Timestamp('2023-04-02 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2023-04-01 00:00:00'),
#   'filing_date': '2023-05-05 00:00:00',
#   'financials': '{"balance_sheet": {"liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 270002000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 7482000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 77130000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 175849000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 62158000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 149927000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 42945000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 332160000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 105431000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 43398000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 62158000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 107600000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 42327000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 112913000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 120075000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 219247000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 332160000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 5155000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -25724000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 25326000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 25326000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 25326000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.53, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 52860000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 41976000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating ...
#   'fiscal_period': 'Q2',
#   'fiscal_year': '2023',
#   'start_date': Timestamp('2023-01-01 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2022-12-31 00:00:00'),
#   'filing_date': '2023-02-03 00:00:00',
#   'financials': '{"balance_sheet": {"liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 290020000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 109400000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 346747000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 346747000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 121957000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 56727000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 57918000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 43334000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 56727000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 137286000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 152734000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 79368000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 6820000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 42951000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 217970000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 128777000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 175019000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -3003000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -35563000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 28195000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 28195000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 28195000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.89, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 66822000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 50332000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operatin ...
#   'fiscal_period': 'Q1',
#   'fiscal_year': '2023',
#   'start_date': Timestamp('2022-09-25 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2022-09-24 00:00:00'),
#   'filing_date': nan,
#   'financials': '{"balance_sheet": {"inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 4946000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 217350000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 50672000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 148101000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 302083000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 352755000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 135405000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 89867000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 50672000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 352755000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 175233000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 64115000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 130459000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 153982000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 42117000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -3884000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -26794000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 18909000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 18909000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 18909000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.29, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 52051000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 38095000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 13201000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 90146000000.0, "xpath": null}}}',
#   'fiscal_period': 'Q4',
#   'fiscal_year': '2022',
#   'start_date': Timestamp('2022-06-26 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2022-09-24 00:00:00'),
#   'filing_date': '2022-10-28 00:00:00',
#   'financials': '{"balance_sheet": {"fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 42117000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 50672000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 135405000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 153982000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 50672000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 89867000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 302083000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 148101000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 130459000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 352755000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 352755000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 4946000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 217350000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 64115000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 175233000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -10952000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -110749000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 88531000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 88531000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 88531000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 6.15, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 223546000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 170782000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 51345000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 394328000000.0, "xpath": null}}}',
#   'fiscal_period': 'FY',
#   'fiscal_year': '2022',
#   'start_date': Timestamp('2021-09-26 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2022-06-25 00:00:00'),
#   'filing_date': '2022-07-29 00:00:00',
#   'financials': '{"balance_sheet": {"equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 183682000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 58107000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 58107000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 5433000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 112292000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 148329000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 108700000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 129873000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 106859000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 40335000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 48343000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 224017000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 336309000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 278202000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 81530000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 39629000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 336309000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -319000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -27445000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 16639000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 16639000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 16639000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.2, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 47074000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 35885000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating  ...
#   'fiscal_period': 'Q3',
#   'fiscal_year': '2022',
#   'start_date': Timestamp('2022-03-27 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2022-03-26 00:00:00'),
#   'filing_date': '2022-04-29 00:00:00',
#   'financials': '{"balance_sheet": {"other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 112720000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 127508000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 350662000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 74826000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 67399000000.0, "xpath": null}, "other_noncurrent_liabilities": {"formula": null, "label": "Other Non-current Liabilities", "order": 820, "unit": "USD", "value": 42755000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 350662000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 5460000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 232482000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 155755000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 118180000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 283263000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 52682000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 67399000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 193178000000.0, "xpath": null}, "fixed_assets": {"formula": null, "label": "Fixed Assets", "order": 320, "unit": "USD", "value": 39304000000.0, "xpath": null}, "long_term_debt": {"formula": null, "label": "Long-term Debt", "order": 810, "unit": "USD", "value": 113000000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -9450000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": -28351000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 19443000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 19443000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 19443000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.54, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 54719000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 42559000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operatin ...
#   'fiscal_period': 'Q2',
#   'fiscal_year': '2022',
#   'start_date': Timestamp('2021-12-26 00:00:00')},
#  {'company_name': 'Apple Inc.',
#   'end_date': Timestamp('2021-12-25 00:00:00'),
#   'filing_date': '2022-01-28 00:00:00',
# ...
#  {'company_name': 'APPLE INC',
#   'end_date': Timestamp('2009-12-26 00:00:00'),
#   'filing_date': '2010-01-25 00:00:00',
#   'financials': '{"balance_sheet": {"liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 18158000000.0, "xpath": null}, "intangible_assets": {"formula": null, "label": "Intangible Assets", "order": 330, "unit": "USD", "value": 241000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 6511000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 33332000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 5061000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 20594000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 576000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 32756000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 35768000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 13097000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 6586000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 20353000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 53926000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 53926000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 35768000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": 2346000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": 523000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 3378000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 3378000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 3.74, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 9272000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 6411000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 1686000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 15683000000.0, "xpath": null}}}',
#   'fiscal_period': 'Q1',
#   'fiscal_year': '2010',
#   'start_date': Timestamp('2009-09-27 00:00:00')},
#  {'company_name': 'APPLE INC',
#   'end_date': Timestamp('2009-09-26 00:00:00'),
#   'filing_date': nan,
#   'financials': '{"balance_sheet": {"other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 13681000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 53851000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 36265000000.0, "xpath": null}, "intangible_assets": {"formula": null, "label": "Intangible Assets", "order": 330, "unit": "USD", "value": 247000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 5601000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 27832000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 27832000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 6737000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 53851000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 17586000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 35810000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 26019000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 17339000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 455000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 19282000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -342000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": 319000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 1741000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 1741000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 5780000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.8599999999999994, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 6256000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 3614000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 1421000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 9870000000.0, "xpath": null}}}',
#   'fiscal_period': 'Q4',
#   'fiscal_year': '2009',
#   'start_date': Timestamp('2009-06-28 00:00:00')},
#  {'company_name': 'APPLE INC',
#   'end_date': Timestamp('2009-09-26 00:00:00'),
#   'filing_date': '2009-10-27 00:00:00',
#   'financials': '{"balance_sheet": {"current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 36265000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 455000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 19282000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 6737000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 53851000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 17339000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 26019000000.0, "xpath": null}, "accounts_payable": {"formula": null, "label": "Accounts Payable", "order": 710, "unit": "USD", "value": 5601000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 35810000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 53851000000.0, "xpath": null}, "equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 27832000000.0, "xpath": null}, "other_current_liabilities": {"formula": null, "label": "Other Current Liabilities", "order": 740, "unit": "USD", "value": 13681000000.0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 17586000000.0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 27832000000.0, "xpath": null}, "intangible_assets": {"formula": null, "label": "Intangible Assets", "order": 330, "unit": "USD", "value": 247000000.0, "xpath": null}}, "cash_flow_statement": {"exchange_gains_losses": null, "net_cash_flow": {"formula": null, "label": "Net Cash Flow", "order": 1100, "unit": "USD", "value": -6612000000.0, "xpath": null}, "net_cash_flow_from_financing_activities": {"formula": null, "label": "Net Cash Flow From Financing Activities", "order": 700, "unit": "USD", "value": 663000000.0, "xpath": null}}, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 5780000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 5780000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 5780000000.0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 6.39, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 23397000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 13140000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 5482000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 36537000000.0, "xpath": null}}}',
#   'fiscal_period': 'FY',
#   'fiscal_year': '2009',
#   'start_date': Timestamp('2008-09-28 00:00:00')},
#  {'company_name': 'APPLE INC',
#   'end_date': Timestamp('2009-06-27 00:00:00'),
#   'filing_date': '2009-07-22 00:00:00',
#   'financials': '{"balance_sheet": {"equity_attributable_to_parent": {"formula": null, "label": "Equity Attributable To Parent", "order": 1600, "unit": "USD", "value": 25888000000.0, "xpath": null}, "noncurrent_liabilities": {"formula": null, "label": "Noncurrent Liabilities", "order": 800, "unit": "USD", "value": 5591000000.0, "xpath": null}, "liabilities_and_equity": {"formula": null, "label": "Liabilities And Equity", "order": 1900, "unit": "USD", "value": 48140000000.0, "xpath": null}, "current_assets": {"formula": null, "label": "Current Assets", "order": 200, "unit": "USD", "value": 35170000000.0, "xpath": null}, "assets": {"formula": null, "label": "Assets", "order": 100, "unit": "USD", "value": 48140000000.0, "xpath": null}, "current_liabilities": {"formula": null, "label": "Current Liabilities", "order": 700, "unit": "USD", "value": 16661000000.0, "xpath": null}, "liabilities": {"formula": null, "label": "Liabilities", "order": 600, "unit": "USD", "value": 22252000000.0, "xpath": null}, "other_noncurrent_assets": {"formula": null, "label": "Other Non-current Assets", "order": 350, "unit": "USD", "value": 12711000000.0, "xpath": null}, "equity_attributable_to_noncontrolling_interest": {"formula": null, "label": "Equity Attributable To Noncontrolling Interest", "order": 1500, "unit": "USD", "value": 0, "xpath": null}, "noncurrent_assets": {"formula": null, "label": "Noncurrent Assets", "order": 300, "unit": "USD", "value": 12970000000.0, "xpath": null}, "intangible_assets": {"formula": null, "label": "Intangible Assets", "order": 330, "unit": "USD", "value": 259000000.0, "xpath": null}, "other_current_assets": {"formula": null, "label": "Other Current Assets", "order": 250, "unit": "USD", "value": 34790000000.0, "xpath": null}, "inventory": {"formula": null, "label": "Inventory", "order": 230, "unit": "USD", "value": 380000000.0, "xpath": null}, "commitments_and_contingencies": {"formula": null, "label": "Commitments and Contingencies", "order": 900, "unit": "USD", "value": 0, "xpath": null}, "equity": {"formula": null, "label": "Equity", "order": 1400, "unit": "USD", "value": 25888000000.0, "xpath": null}}, "cash_flow_statement": null, "comprehensive_income": {"comprehensive_income_loss": {"formula": null, "label": "Comprehensive Income/Loss", "order": 100, "unit": "USD", "value": 1229000000.0, "xpath": null}, "comprehensive_income_loss_attributable_to_parent": {"formula": null, "label": "Comprehensive Income/Loss Attributable To Parent", "order": 300, "unit": "USD", "value": 1229000000.0, "xpath": null}, "other_comprehensive_income_loss": {"formula": null, "label": "Other Comprehensive Income/Loss", "order": 400, "unit": "USD", "value": 0, "xpath": null}}, "income_statement": {"basic_earnings_per_share": {"formula": null, "label": "Basic Earnings Per Share", "order": 4200, "unit": "USD / shares", "value": 1.38, "xpath": null}, "cost_of_revenue": {"formula": null, "label": "Cost Of Revenue", "order": 300, "unit": "USD", "value": 5314000000.0, "xpath": null}, "gross_profit": {"formula": null, "label": "Gross Profit", "order": 800, "unit": "USD", "value": 3023000000.0, "xpath": null}, "operating_expenses": {"formula": null, "label": "Operating Expenses", "order": 1000, "unit": "USD", "value": 1351000000.0, "xpath": null}, "revenues": {"formula": null, "label": "Revenues", "order": 100, "unit": "USD", "value": 8337000000.0, "xpath": null}}}',
#   'fiscal_period': 'Q3',
#   'fiscal_year': '2009',
#   'start_date': Timestamp('2009-03-29 00:00:00')}]
